# %% [markdown]
# # Tuple

# %% [markdown]
# ###`Q1:` Join Tuples if similar initial element
# While working with Python tuples, we can have a problem in which we need to perform concatenation of records from the similarity of initial element. This problem can have applications in data domains such as Data Science.
#
# For eg.
# ```
# Input  : test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]
# Output : [(5, 6, 7, 8), (6, 10), (7, 13)]
# ```

# %%
# write your code here

test_list = [(5, 6), (5, 7), (5, 8), (6, 10), (7, 13)]

temp = {}
for a,b in test_list:
  if a not in temp:
    temp[a] = [a]
  temp[a].append(b)
  result = [tuple(values) for values in temp.values()]
print(result)
# Out:
# [(5, 6, 7, 8), (6, 10), (7, 13)]

# %% [markdown]
# ###`Q2:` Multiply Adjacent elements (both side) and take sum of right and lest side multiplication result.
#
#
# For eg.
# ```
# The original tuple : (1, 5, 7, 8, 10)
# Resultant tuple after multiplication :
#
# (1*5, 1*5+5*7, 7*5 + 7*8, 8*7 + 8*10, 10*8) -> (5, 40, 91, 136, 80)
#
# output-(5, 40, 91, 136, 80)
# ```

# %%
# write your code here

tup = (1, 5, 7, 8, 10)

result = ()
for i in range(len(tup)):
  if i == 0:
    j = tup[i]*tup[i+1]
  elif i == len(tup)-1:
    j = tup[i-1]*tup[i]
  else:
    j = tup[i-1]*tup[i] + tup[i]*tup[i+1]
  result += j,
print(result)
# Out:
# (5, 40, 91, 136, 80)

# %% [markdown]
# ###`Q3`: Check is tuples are same or not?
# Two tuples would be same if both tuples have same element at same index
# ```
# t1 = (1,2,3,0)
# t2 = (0,1,2,3)
#
# t1 and t2 are not same
# ```

# %%
# write your code here

t1 = (1,2,3,0)
t2 = (0,1,2,3)

if t1 == t2:
  print("t1 and t2 are same")
else:
  print("t1 and t2 are not same")

# or

flag = True
for i in range(len(t1)):
  if t1[i] != t2[i]:
    flag = False
    break
if flag:
  print("t1 and t2 are same")
else:
  print("t1 and t2 are not same")
# Out:
# t1 and t2 are not same

# %% [markdown]
# ###`Q4`: Count no of tuples, list and set from a list
# ```
# list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]
#
# ```
# `Output:`
#
# ```
# List-2
# Set-2
# Tuples-1
# ```

# %%
# write your code here

list1 = [{'hi', 'bye'},{'Geeks', 'forGeeks'},('a', 'b'),['hi', 'bye'],['a', 'b']]


List = 0
Tuple = 0
Set = 0

for i in list1:
  if type(i) == list:
    List += 1
  elif type(i) == set:
    Set += 1
  elif type(i) == tuple:
    Tuple += 1
print("number of lists are:", List)
print("Number of Tuples are :", Tuple)
print("Number of Sets are:", Set)
# Out:
# number of lists are: 0
# Number of Tuples are : 1
# Number of Sets are: 2

# %% [markdown]
# ###`Q5`: Shortlist Students for a Job role
# Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# Show every students record in form of tuples if matches all required criteria.
#
# It is assumed that there will be only one primry skill.
#
# If no such candidate found, print `No such candidate`
#
# `Input:`
# ```
# Enter No of records- 2
# Enter Details of student-1
# Enter Student name- Manohar
# Enter Higher Education- B.Tech
# Enter Primary Skill- Python
# Enter Year of Graduation- 2022
# Enter Details of student-2
# Enter Student name- Ponian
# Enter Higher Education- B.Sc.
# Enter Primary Skill- C++
# Enter Year of Graduation- 2020
#
# Enter Job Role Requirement
# Enter Skill- Python
# Enter Higher Education- B.Tech
# Enter Year of Graduation- 2022
# ```
#
# `Output`
# ```
# ('Manohar', 'B.tech', 'Python', '2022')
# ```

# %%
# write your code here

students = []
n = int(input("Enter the number of students: "))

for i in range(n):
  name  = input("enter the name of the student: ")
  Higher_Education = input("enter the higher education: ")
  Primary_Skill = input("enter the Primary Skill: ")
  Year_of_Graduation = input("enter the year of graduation: ")

  students.append((name,Higher_Education,Primary_Skill,Year_of_Graduation))

# Job Role Requirement

req_Higher_Education = input("enter the required higher education: ")
req_Primary_Skill = input("enter the required Primary Skill: ")
req_Year_of_Graduation = input("enter the required year of graduation: ")

matched = []
for s in students:
  if s[1] == req_Higher_Education and s[2] == req_Primary_Skill and s[3] == req_Year_of_Graduation:
    matched.append(s)

if matched:
  for m in matched:
    print(m)
else:
  print("No such candidate")
# Out:
# Enter the number of students: 2
# enter the name of the student: Manohar
# enter the higher education: B.Tech
# enter the Primary Skill: Python
# enter the year of graduation: 2022
# enter the name of the student: Ponian
# enter the higher education: B.Sc.
# enter the Primary Skill: C++
# enter the year of graduation: 2020
# enter the required higher education: B.Tech
# enter the required Primary Skill: Python
# enter the required year of graduation: 2022
# ('Manohar', 'B.Tech', 'Python', '2022')

# %% [markdown]
# # Set

# %% [markdown]
# ###`Q1:` Write a program to find set of common elements in three lists using sets.
# ```
# Input : ar1 = [1, 5, 10, 20, 40, 80]
#         ar2 = [6, 7, 20, 80, 100]
#         ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
#
# Output : [80, 20]
# ```

# %%
# write your code here

ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]

result = (set(ar1) & set(ar2) & set(ar3))
print(list(result))
# Out:
# [80, 20]

# %% [markdown]
# ###`Q2:` Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.
#
# `Input:`
# ```
# Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
# ```
# `Output:`
# ```
# No of unique vowels-6
# ```

# %%
# write your code here

Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"

vowel = {'a','e','i','o','u','A','E','I','O','U'}
result = len(set(Str1).intersection(vowel))
print("No of unique vowels-",result)
# Out:
# No of unique vowels- 6

# %% [markdown]
# ### `Q3:` Write a program to Check if a given string is binary string of or not.
#
# A string is said to be binary if it's consists of only two unique characters.
#
# Take string input from user.
#
# ```
# Input: str = "01010101010"
# Output: Yes
#
# Input: str = "1222211"
# Output: Yes
#
# Input: str = "Campusx"
# Output: No
# ```

# %%
# write your code here

str1 = input("Enter the string:")
unique_char = len(set(str1))

if unique_char == 2:
  print("Yes, string is binary")

else:
  print("String is not binary")
# Out:
# Enter the string:Campusx
# String is not binary

# %% [markdown]
# ### `Q4`: find union of n arrays.
#
# **Example 1:**
#
# Input:
# ```bash
# [[1, 2, 2, 4, 3, 6],
#  [5, 1, 3, 4],
#  [9, 5, 7, 1],
#  [2, 4, 1, 3]]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5, 6, 7, 9]
# ```

# %%
# write your code here

array = [[1, 2, 2, 4, 3, 6],
 [5, 1, 3, 4],
 [9, 5, 7, 1],
 [2, 4, 1, 3]]

union_set = set()
for i in range(len(array)):
  subset = set(array[i])
  union_set.update(union_set|subset)
print(union_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}

# %% [markdown]
# ### `Q5`: Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using **list-comprehension**.
#
# **Example 1:**
#
# Input:
# ```bash
# lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}
# ```
#
# Output:
# ```bash
# [9, 10, 4, 5]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# lst1 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
# lst2 = {9, 9, 74, 21, 45, 11, 63, 28, 26}
# ```
#
# Output:
# ```bash
# [9, 11, 26, 28]
# ```

# %%
# write your code here

#Example 1
lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}

print([i for i in lst1 if i in lst2])


# Example 2
lst3 = {4, 9, 1, 17, 11, 26, 28, 54, 69}
lst4 = {9, 9, 74, 21, 45, 11, 63, 28, 26}

print([i for i in lst3 if i in lst4])
# Out:
# [4, 5, 9, 10]
# [9, 11, 26, 28]

# %% [markdown]
# # Dictionary

# %% [markdown]
# ### `Q1`: Key with maximum unique values
#
# Given a dictionary with values list, extract key whose value has most unique values.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# CampusX
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_dict = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}
# ```
#
# Output:
# ```bash
# Best
# ```

# %%
# write your code here

test_dict = {"CampusX" : [5, 7, 9, 4, 0], "is" : [6, 7, 4, 3, 3], "Best" : [9, 9, 6, 5, 5]}

max_key  = None
max_unique = 0
for key in test_dict:
  value = len(set(test_dict[key]))

  if value > max_unique:
    max_unique = value
    max_key = key
print("Key with maximum unique values:", max_key)

# Example 2:

test_dict1 = {"CampusX" : [5, 7, 7, 7, 7], "is" : [6, 7, 7, 7], "Best" : [9, 9, 6, 5, 5]}

max_key1  = None
max_unique1 = 0
for key in test_dict1:
  value1 = len(set(test_dict1[key]))

  if value1 > max_unique1:
    max_unique1 = value1
    max_key1 = key
print("Key with maximum unique values:", max_key1)
# Out:
# Key with maximum unique values: CampusX
# Key with maximum unique values: Best

# %% [markdown]
# ### `Q2`: Replace words from Dictionary. Given String, replace it’s words from lookup dictionary.
#
# **Example 1:**
#
# Input:
#
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}
# ```
#
# Output:
#
# ```bash
# CampusX is the best channel for Data-Science students.
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_str = 'CampusX best for DS students.'
# repl_dict = {"good" : "is the best channel", "ds" : "Data-Science"}
# ```
#
# Output:
# ```bash
# CampusX best for DS students.
# ```

# %%
# write your code here

test_str = 'CampusX best for DS students.'
repl_dict = {"best" : "is the best channel", "DS" : "Data-Science"}

words = test_str.split()

lst = []
for word in words:
  if word in repl_dict:
    lst.append(repl_dict[word])
  else:
    lst.append(word)
print(" ".join(lst))
# Out:
# CampusX is the best channel for Data-Science students.

# %% [markdown]
# ### `Q3`: Convert List to List of dictionaries. Given list values and keys list, convert these values to key value pairs in form of list of dictionaries.
#
# **Example 1:**
#
# Input:
# ```bash
# test_list = ["DataScience", 3, "is", 8]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# test_list = ["CampusX", 10]
# key_list = ["name", "id"]
# ```
#
# Output:
#
# ```bash
# [{'name': 'CampusX', 'id': 10}]
# ```

# %%
# write your code here

test_list = ["DataScience", 3, "is", 8]
key_list = ["name", "id"]

result = []
for i in range(0,len(test_list),len(key_list)):
  temp = dict(zip(key_list,test_list[i:i+len(key_list)]))
  result.append(temp)

print(result)
# Out:
# [{'name': 'DataScience', 'id': 3}, {'name': 'is', 'id': 8}]

# %% [markdown]
# ### `Q4`: Convert a list of Tuples into Dictionary.
#
# **Example 1:**
#
# Input:
# ```bash
# [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# ```
#
# Output:
# ```bash
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# ```
#
# **Example 2:**
#
# Input:
# ```bash
# [('A', 1), ('B', 2), ('C', 3)]
# ```
#
# Output:
# ```bash
# {'A': [1], 'B': [2], 'C': [3]}
# ```

# %%
# write your code here

inpt = [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]

result = {}
for key,value in inpt:
  result[key] = [value]
print(result)
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}

# %% [markdown]
# ### `Q5`: Sort Dictionary key and values List.
#
# **Example 1:**
#
# Input:
#
# ```bash
# {'c': [3], 'b': [12, 10], 'a': [19, 4]}
# ```
#
# Output:
#
# ```bash
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
# ```
#
# **Example 2:**
#
# Input:
#
# ```bash
# {'c': [10, 34, 3]}
# ```
#
# Output:
#
# ```bash
# {'c': [3, 10, 34]}
# ```

# %%
# write your code here

d = {'c': [3], 'b': [12, 10], 'a': [19, 4]}

for key in d:
  d[key].sort()

result = dict(sorted(d.items()))

print(result)


# Example : 2

d = {'c': [10, 34, 3]}

for key in d:
    d[key].sort()

print(d)
# Out:
# {'a': [4, 19], 'b': [10, 12], 'c': [3]}
# {'c': [3, 10, 34]}
